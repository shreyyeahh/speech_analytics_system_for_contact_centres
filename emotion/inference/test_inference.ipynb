# %%
import sys
sys.path.insert(0, "E:\\speech_analytics_system_for_contact_centres")

from emotion.inference.emotion_inference import predict_emotion

result = predict_emotion("E:\\speech_analytics_system_for_contact_centres\\Audio_Speech_Actors_01-24\\Actor_23\\03-01-02-01-02-01-23.wav")
print(result)
# Out:
# {'emotion': 'calm', 'confidence': 0.76, 'probabilities': {'neutral': 0.055, 'calm': 0.76, 'happy': 0.015, 'sad': 0.035, 'angry': 0.025, 'fearful': 0.045, 'disgust': 0.05, 'surprised': 0.015}}
